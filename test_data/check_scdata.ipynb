# %% [markdown]
# # Import packages

# %%
import scanpy as sc

# %%
sc.settings.set_figure_params(dpi=150, dpi_save=300)

# %% [markdown]
# # Load data

# %%
adata = sc.read_h5ad("scdata.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 15615 × 2156
#     obs: 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'doublet_score', 'predicted_doublet', 'n_counts', 'S_score', 'G2M_score', 'phase', 'dbscan_clusters', 'dpt_pseudotime', 'leiden', 'celltype', 'hto_ass', 'hto_zone', 'hto_sum', 'batch_name'
#     var: 'gene_ids', 'feature_types', 'genome', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection', 'mean', 'std'
#     uns: 'batch_colors', 'batch_name_colors', 'celltype_colors', 'dbscan_clusters_colors', 'dendrogram_celltype', 'dendrogram_dbscan_clusters', 'dendrogram_leiden', 'hto_zone_colors', 'leiden', 'leiden_colors', 'neighbors', 'pca', 'phase_colors', 'umap'
#     obsm: 'X_pca', 'X_scanorama', 'X_umap'
#     varm: 'PCs'
#     layers: 'lognorm'
# ...

# %%
sc.pl.umap(
    adata,
    color=[
        "celltype",
        "dpt_pseudotime",
        "phase",
        "batch",
        "n_genes_by_counts",
        "total_counts",
    ],
    wspace=0.8,
    ncols=2,
)
# Out:
# /mnt/weird_vol/miniforge3/envs/downstr/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /mnt/weird_vol/miniforge3/envs/downstr/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /mnt/weird_vol/miniforge3/envs/downstr/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# # Geneset/Marker lists

# %%
marker_genes_svz_lineage_dict = dict(
    {
        "qNSC1": ["Aqp4", "Cxcl14"],
        "qNSC2": ["Cpe", "S100a6"],
        "aNSC1": ["Btg2", "Egr1"],
        "aNSC2": ["Egfr", "Ascl1", "Top2a"],
        "TAP": ["Mki67", "Ube2c"],
        "NB": ["Dcx", "Stmn2"],
    }
)

# %%
marker_genes_svz_lineage_dict_collapsed = {
    "qNSCs": ["Aqp4", "Cxcl14", "Cpe", "S100a6"],
    "aNSCs": ["Btg2", "Egr1", "Egfr", "Ascl1", "Top2a"],
    "TAP": ["Mki67", "Ube2c"],
    "NB": ["Dcx", "Stmn2"],
}

marker_genes_svz_lineage_dict_collapsed
# Out:
# {'qNSCs': ['Aqp4', 'Cxcl14', 'Cpe', 'S100a6'],
#  'aNSCs': ['Btg2', 'Egr1', 'Egfr', 'Ascl1', 'Top2a'],
#  'TAP': ['Mki67', 'Ube2c'],
#  'NB': ['Dcx', 'Stmn2']}
